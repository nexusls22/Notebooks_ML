# %%
import numpy as np
import pandas as pd
from itables import init_notebook_mode, show

df = pd.read_csv('Lab_attacks.csv',encoding = 'ISO-8859-1')
selection=df[['Country']].value_counts().head(1)
print(selection)

print()
selectio1n=df[['Country', 'Fatal']].value_counts().head(6)
print(selection1)

surf_select=df[df['Activity'].isin(['Surfing'])]['Activity'].value_counts()
scuba_select=df[df['Activity'].isin(['Scuba Diving'])]['Activity'].value_counts()
print(surf_select)
print(scuba_select)

print('Most likely get attacked at: \n', df[df['Activity'] == 'Surfing'][['Activity']].head(1))

selection2=df[df['Fatal'] == 'Y'][['Fatal']].value_counts()
percentage=selection2/len(df)*100
print(selection2)
print(len(df))

print('Percentage of an attack being fatal is at ', percentage, ' percent')
# Out:
# Country
# USA        2160
# Name: count, dtype: int64
#
#             Activity
# 0      Body boarding
# 1            Surfing
# 2            Surfing
# 3           Surfing
# 4       Spearfishing
# ...              ...
# 25609            NaN
# 25610            NaN
# 25611            NaN
# 25612            NaN
# 25613            NaN
#
# [25614 rows x 1 columns]
# Activity
# Surfing    931
# Name: count, dtype: int64
# Activity
# Scuba Diving    6
# Name: count, dtype: int64
# Most likely get attacked at:
#    Activity
# 1  Surfing
# Fatal
# Y        1566
# Name: count, dtype: int64
# 25614
# Percentage of an attack being fatal is at  Fatal
# Y        6.113844
# Name: count, dtype: float64  percent

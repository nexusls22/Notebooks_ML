# %% [markdown]
# # Machine Learning
# ## Lab 01
# ## Dr. Abubakr Siddig

# %% [markdown]
# # **Let's start with your first notebook for ML**
#
# ***
# This is a **cell**. Each cell can contain either *Markdown* or *code*.
# This is a markdown cell which is used to display text.
#
# Markdown is a lightweight, easy to learn markup language for formatting plain text. Its syntax is similar to HTML.
#
# If you double click this cell, you can see it in raw form. If you run the cell, it will be formatted once again. You can run by clicking the run button, or by pressing **Ctrl + Enter**.
# ***

# %% [markdown]
# There are a lot of cool things that can be done using Markdown.
#
# # This is a level 1 heading
# ## This is a level 2 heading
# This is some plain text that forms a paragraph.
# Add emphasis via **bold** and __bold__, or *italic* and _italic_.
# Paragraphs must be separated by an empty line.
#
# * Sometimes we want to include lists.
#   * Which can be indented.
#
#  1. Lists can also be numbered.
#  2. For ordered lists.
#
# [It is possible to include hyperlinks](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet)
#
# Inline code uses single backticks: `foo()`, and code blocks use triple backticks:
# ```
# bar()
# ```
#
#
# You can make a cell into a Markdown cell by selecting it in the dropdown menu or by pressing M when selected.
#
# **(Double click this cell to see the raw Markdown text)**

# %% [markdown]
# So now that we've seen what Markdown can do, what about actual code?
#
# Under this cell, is a **code cell**. By selecting that cell and pressing run or *Ctrl+Enter*, the code snippet will run. Each individual cell can be run in a Notebook. You can also run all cells by click the 'Cell' dropdown and selecing 'Run All'.

# %%
print("Hello World")

# %% [markdown]
# Great! We've actually run Python code now.
#
# It’s common to start off with a code cell specifically for imports and setup, so that if you choose to add or change anything, you can simply edit and re-run the cell without causing any side-effects. Let's do that next.
#
# We're going to import numpy. It's common practice to import it as np, to save on typing when calling the library's built-in functions.

# %%
import math
print("Imported math")

# %% [markdown]
# ehind every notebook runs a kernel. When you run a code cell, that code is executed within the kernel and any output is returned back to the cell to be displayed. The kernel’s state persists over time and between cells — it pertains to the document as a whole and not individual cells.
#
# This means that if you import libraries or declare variables in one cell, they will be available in another. In this way, you can think of a notebook document as being somewhat comparable to a script file, except that it is multimedia.

# %% [markdown]
# ## Basic Math with Python
# We are going to start with some very basic Python commands in colab.

# %%
1+1

# %%
math.sin(1)

# %%
math.sqrt(9)

# %%
math.pi

# %%
math.sqrt(math.pi)

# %% [markdown]
# ## Combining Functions

# %%
print(math.sqrt(4))

# %%
print('The square root of 4 is', math.sqrt(4))

# %% [markdown]
# ## Variables

# %% [markdown]
# A variable can be used to store values calculated in expressions and used for other calculations. Assigning values to variables is straightforward. To assign a value, you simply type `variable_name = value`, where `variable_name` is the name of the variable you wish to define. In the cell below, define a variable called `temp_celsius`, assign it a value of ‘10.0’, and then print that variable value using the `print()` function. Note that you should do this on two separate lines.

# %%
temp_cel = 10.0
print(temp_cel)

# %% [markdown]
# ###Task 1
# Calculate the temperature from above in Fahrenheit and `print` the result. The formula is: temperature in celsius * (9/5) + 32

# %%
temp_cel = 10.0
temp_fh = temp_cel * (9/5) + 32

print('Tempreture in Farenheit: ', temp_fh)
# Out:
# Tempreture in Farenheit:  50.0

# %% [markdown]
# ###Task 2
# Set a new value to `temp_cel`. Try to **use** a variable name that doesn't exist (yet) called `temp_far` and print it out. What error do you get?

# %%
# print(temp_far). # first time Causes a NameError
print(temp_far) # after defining it in a lower cell this will suddenly work
temp_cel = 15.0
print(temp_cel)
# Out:
# 50.0
# 15.0

# %% [markdown]
# ###Task 3
# Create the variable `temp_far` with the following formula: (9/5) * temp_cel +32 Run the cell you create it in. Then re-run the previous cell. You will find that you won't get the error anymore. Also run a `print` after defining the temp_far variable to check the values in both variables.

# %%
temp_far = 9/5 * temp_cel + 32
print('Temperature in Celsius:', temp_cel, 'and in Fahrenheit:', temp_far)
# Out:
# Temperature in Celsius: 10.0 and in Fahrenheit: 50.0

# %% [markdown]
# ###Task 4
# Change the value of the temp_cel variable and print both out again.

# %%
temp_cel + 32
print('Temperature in Celsius:', temp_cel, 'and in Fahrenheit:', temp_far)
# Out:
# Temperature in Celsius: 15.0 and in Fahrenheit: 50.0

# %% [markdown]
# ## Data Types

# %% [markdown]
# Python has four basic data types: int, float, str and bool. As part of this course we will get to know many more that are useful for spatial analytical and general analytical tasks.
#
# Data Type | Description | Example
# --- | --- | ---
# int | A whole integer number | 34
# float | Decimal values | 3.4
# str | Character strings | "I love Python in Colab"
# bool | `True` or `False` values | `True`

# %% [markdown]
# ###Task 5
# Define a variable called `weather_forecast` and set a value of "snow". Check the data type of this variable using type and print it out.

# %%
weather_forecast = "snow"
print('Weather forcast type: ', type(weather_forecast))
# Out:
# Weather forcast type:  <class 'str'>

# %% [markdown]
# ###Task 6
# Check what happens if you combine them. Use your previous `temp_far` variable and add 5.0 to it using the + operator and then add `weather_forecast` to it, too. What happens?

# %%
temp_far += 5.0
print('The forecast is: ', weather_forecast, 'with a tempreture of: ', temp_far, ' Farenheit')
# Out:
# The forecast is:  snow with a tempreture of:  55.0  Farenheit

# %% [markdown]
# ###Task 7
# Create two variables and fill them with character string values. Can you add or substract these values to/from each other? Can you multiply them by a number?

# %%
str1 = 'Hello'
str2 = 'World'

print(str1 + str2, str1 * 3)
print(str1 - str2)
# Out:
# HelloWorld HelloHelloHello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       2 str2 = 'World'
#       4 print(str1 + str2, str1 * 3)
# ----> 5 print(str1 - str2)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# ## Character Input

# %% [markdown]
# We can use `input()` to ask for user input.
#
# ###Task 8
# Define a varaible `place` and assign its value using the `input()` function to prompt the user for the location where they are from (e.g., `input('Where are you from? ')`). When the cell is run, the user (you) can type in their response. Once `place` is defined, we can say something good about where the user is from (e.g., `print(place, 'is a nice place!')`).

# %%
# your code goes into this cell
place = input('Where are you from?')
print(place, 'is a nice place!')
# Out:
# Where are you from? Germany
# Germany is a nice place!

# %% [markdown]
# ###Task 9
# What data type is place?

# %%
print(type(place))
# Out:
# <class 'str'>

# %% [markdown]
# ###Task 10
# Ask the user for a temperature value in Celsius. Then use the formula from earlier to convert this temperature into Fahrenheit.
# Does this work out of the box or do you have to do any type casting? Type casting in Python is done by using the type you want to cast into and give it the value in another type.
#
# Example:
#
# ```
# my_string = "32"
# print(type(my_string)) # result is <class 'str'>
# my_int = int(my_string) # result is <class 'int'>
# print(type(my_int))
# ```
# If this example seems difficult, try it out in its own code cell before attempting to solve the task.
#
# Alternatively, you can open a scratch editor under the menue option
# ```Insert > Scratch code cell```

# %%
# your code goes here
temp_cel = input('What is the temperature right now? ')
temp_far = int(temp_cel) * (9/5) + 32
print(temp_far)
# Out:
# What is the temperature right now?  5
# 41.0

# %% [markdown]
# ###Task 11
# Practice simple conditionals by checking if your entered celsius temperature means that we are either at freezing point, below freezing point, or above freezing point.
#
# Be mindful of the difference between
# ```
# if....
# elif....
# else...
# ```
#
# and
#
# ```
# if...
# if...
# else...
# ```

# %%
# your code goes here
if int(temp_cel) < 0: 
    print('Temperature is below freezing point.')
elif int(temp_cel) > 0: 
    print('Temperature is above freezing point.')
else: 
    print('Temperature is at freezing point')
# Out:
# Temperature is above freezing point.

# %% [markdown]
# ## Functions

# %% [markdown]
# ###Task 12
# Create a function for your celsius to fahrenheit conversion. Your function should take the celsius value as an argument and return the fahrenheit value. Use the function by printing out the returned value.
#
# Functions in Python are defined with the key word ```def``` at the beginning. The content of the function must be indented. Not every function contains arguments. Not every function has a return value. The following example takes one argument and returns a value.
#
# Example function definition:
# ```
# def print_me(to_print):
#   print(to_print)
#   return True
# ```
#
# Example function call:
# ```
# success = print_me("hello world")
# print(success)
# ```
# running the function will print ```True```

# %%
# your code goes into this cell
def convert_cel_to_far(temp_cel):
    temp_far = int(temp_cel) * (9/5) + 32
    return temp_far

print(convert_cel_to_far(temp_cel))
# Out:
# 41.0

# %% [markdown]
# ## Higher Data Types

# %% [markdown]
# ### Lists
# List is a popular Python data type to store more than one value at any one time.
# Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set, and Dictionary, all with different qualities and usage.
#
# Lists are created using square brackets. Elements can be accessed using their index position. The index position of an element does not change. A list can contain elements of varying types.
#
# **Example**:
#
# ```
# my_list = ['red', 'green', 'blue']
# print(my_list)
# print(my_list[0])
# print(my_list[-1))  # accessing elements using their index position
# print(my_list[1:2]) # slicing notation
# print(len(my_list))
# ```

# %% [markdown]
# #### Task 13
#
# *   Set up a list of three train stations in Ireland.
# *   What data type does Python think this is?
# *   Print the content to screen.
# *   Print only the second element to screen.
# *   Print the last element to screen.
# *   Print the second element to screen using slicing.
# *   Print how many items your list contains.
# *   Change the second element in your list to something with an integer value and print out the modified list.
# *   Delete the first element and print out the modified list.
# *   Create a new list that is a copy of the old list.
# *   Modify your train station list by appending an element. Does the copy reflect the change? How can a list be copied to either reflect the change of the original and how can it be set up to not reflect the change of the original.
# *   Using a basic loop print out each element of your list (inline or not)

# %%
# your code goes into this cell
train_station_list = ['Dublin Pearse', 'Dublin Heuston', 'Docklands']

print(type(train_station_list))

for i in range(len(train_station_list)):
    print(train_station_list[i])

if train_station_list[0]: 
    print(train_station_list[0])

if train_station_list[2]: 
    print(train_station_list[2])
# Out:
# <class 'list'>
# Dublin Pearse
# Dublin Heuston
# Docklands
# Dublin Pearse
# Docklands

# %% [markdown]
# # Jupyter and Machine learning

# %% [markdown]
# The main python tool we will be using is the scikit-learn library. Data in scikit-learn, with very few exceptions, is assumed to be stored as a two-dimensional array, of shape [n_samples, n_features].

# %% [markdown]
# $$\mathbf{X} = \begin{bmatrix}
#     x_{1}^{(1)} & x_{2}^{(1)} & x_{3}^{(1)} & \dots  & x_{n\_features}^{(1)} \\
#     x_{1}^{(2)} & x_{2}^{(2)} & x_{3}^{(2)} & \dots  & x_{n\_features}^{(2)} \\
#     \vdots & \vdots & \vdots & \ddots & \vdots \\
#     x_{1}^{(n\_samples)} & x_{2}^{(n\_samples)} & x_{3}^{(n\_samples)} & \dots  & x_{n\_features}^{(n\_samples)}
# \end{bmatrix}.
# $$
#
# (The superscript denotes the *i*th row, and the subscript denotes the *j*th feature, respectively.

# %% [markdown]
# - **n_samples:**   The number of samples: each sample is an item to process (e.g. classify).
#   A sample can be a document, a picture, a sound, a video, an astronomical object,
#   a row in database or CSV file,
#   or whatever you can describe with a fixed set of quantitative traits.
# - **n_features:**  The number of features or distinct traits that can be used to describe each
#   item in a quantitative manner.  Features are generally real-valued, but may be Boolean or
#   discrete-valued in some cases.

# %% [markdown]
# ## Numpy Arrays

# %% [markdown]
# Manipulating numpy arrays is an important part of doing machine learning (or, really, any type of scientific computation) in python. This will likely be a short review for most. In any case, let's quickly go through some of the most important features.

# %% [markdown]
# Now, we need to run a cell containing import numpy as np

# %%
import numpy as np

# %%
rnd = np.random.RandomState(seed=123)
X = rnd.uniform(low=0.0, high=1.0, size=(1, 5))  # a 1 x 5 array
print(X)
# Out:
# [[0.69646919 0.28613933 0.22685145 0.55131477 0.71946897]]

# %% [markdown]
# Now, reproduce another random vector W with the same code as above. Do this in the cell below.

# %%
# vector W
W = rnd.uniform(low=0.0, high=1.0, size=(1,5))
print(W)
# Out:
# [[0.34317802 0.72904971 0.43857224 0.0596779  0.39804426]]

# %% [markdown]
# What do you notice about X and W? and Why? Write your answer in the cell below

# %% [markdown]
# All values between 0 and 1, because with low and high we set the boundries. Important for normalization, we want a value between 0 and 1.

# %% [markdown]
# Whatever you noticed in X and W, do you think this is important in ML? and why?

# %% [markdown]
# ## Brief Intro to Pandas
#
# Pandas is a modern, powerful and feature rich library that is designed for doing data analysis in Python. It is a mature data analytics framework (originally written by Wes McKinney) that is widely used among different fields of science, thus there exists a lot of good examples and documentation that can help you get going with your data analysis tasks.
#
# In Pandas the data is typically stored into a DataFrame that looks like a typical table with rows and columns (+ indices and column names), where columns can contain data of different data types. Thus, it reminds of how the data is stored e.g. in Excel or in R that also uses a concept of a dataframe. In fact, Wes McKinney first developed Pandas as an alternative for R to deal with different complex data structures.
#
# Pandas takes advantage of numpy -module which runs under the hood and is mostly written in C, which makes it fast and powerful library that can handle efficiently even large datasets. Pandas offers easier and more intuitive syntax to do data analysis and manipulation using either numpy functionalities in the background or dedicated functionalities written explicitly for Pandas. However, Pandas is much more than easier-to-use numpy as it also combines many functionalities from other Python libraries such as matplotlib (plotting) and scipy (mathematics, science, engineering). Thus, you can use many of the features included in those packages even without importing them at all.

# %% [markdown]
# ### Working with Data
#
# Let's learn how to read and explore data files in Python. We will first get familiar with the pandas data structures: DataFrame and Series:

# %% [markdown]
# ![Screenshot 2021-01-07 at 15.16.21.png](data:image/png;base64,...)

# %% [markdown]
# As you can see, both DataFrames and Series in pandas have an index that can be used to select values, but they also have column labels to identify columns in DataFrames.

# %% [markdown]
# First we learn how to connect our google drive with google colab. For this you need to mount your drive.
#
# Run the following, then follow the outputs, log in with the account you want and navigate to your file and confirm.
#
# ```
# from google.colab import drive
# drive.mount("/content/gdrive")
# ```
#
# For the exercise you need to add the file I provided in moodle to your google drive. This file was downloaded from https://data.gov.ie/en_GB/dataset/dublin-airport-monthly-data/resource/f43c57e5-5bab-4dc2-9318-24c31525878a

# %% [markdown]
# Create a folder called `data_share` in your Google Drive directory. Store all the data that you are going to use in this course here.

# %%
from google.colab import drive
drive.mount("/content/gdrive")

# %%
import pandas as pd

# %%
# you need to adjust this path to whatever it is in your google drive
data = pd.read_csv('mly532.csv', skiprows=19)
data.head()
# Out:
#    year  month  meant  maxtp  mintp  mnmax  mnmin  rain   gmin  wdsp maxgt  \
# 0  1941     11    6.9   14.0   -3.1    9.9    3.9  67.2   -5.7  12.0
# 1  1941     12    6.5   12.7   -3.6    9.1    3.9  41.7   -7.6  12.5
# 2  1942      1    4.3   11.9   -3.1    6.9    1.7  91.9   -9.5  13.1
# 3  1942      2    2.9   11.6   -4.3    5.8   -0.0  25.8  -10.7   9.0
# 4  1942      3    6.3   16.2   -6.1    9.4    3.2  76.4   -8.3  10.7
#
#     sun
# 0  56.1
# 1  46.1
# 2  72.8
# 3  51.4
# 4  73.9

# %%
data.tail()
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin   rain  gmin  wdsp maxgt  \
# 968  2022      7   16.3   29.1    6.6   21.0   11.7   29.6   0.0   8.1    33
# 969  2022      8   15.9   26.3    6.0   21.3   10.5   34.6   0.9   7.3    30
# 970  2022      9   13.0   20.1    3.1   17.2    8.8  127.9  -0.3   8.7    39
# 971  2022     10   12.0   18.0    1.3   15.6    8.4  106.8  -3.3   9.6    41
# 972  2022     11    8.8   16.5   -0.8   11.7    6.0   46.1  -3.5   9.9    51
#
#        sun
# 968  131.6
# 969  222.0
# 970  112.9
# 971  115.7
# 972   84.5

# %%
data.head(4)
# Out:
#    year  month  meant  maxtp  mintp  mnmax  mnmin  rain   gmin  wdsp maxgt  \
# 0  1941     11    6.9   14.0   -3.1    9.9    3.9  67.2   -5.7  12.0
# 1  1941     12    6.5   12.7   -3.6    9.1    3.9  41.7   -7.6  12.5
# 2  1942      1    4.3   11.9   -3.1    6.9    1.7  91.9   -9.5  13.1
# 3  1942      2    2.9   11.6   -4.3    5.8   -0.0  25.8  -10.7   9.0
#
#     sun
# 0  56.1
# 1  46.1
# 2  72.8
# 3  51.4

# %%
data.tail(4)
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin   rain  gmin  wdsp maxgt  \
# 969  2022      8   15.9   26.3    6.0   21.3   10.5   34.6   0.9   7.3    30
# 970  2022      9   13.0   20.1    3.1   17.2    8.8  127.9  -0.3   8.7    39
# 971  2022     10   12.0   18.0    1.3   15.6    8.4  106.8  -3.3   9.6    41
# 972  2022     11    8.8   16.5   -0.8   11.7    6.0   46.1  -3.5   9.9    51
#
#        sun
# 969  222.0
# 970  112.9
# 971  115.7
# 972   84.5

# %%
type(data)
# Out:
# pandas.DataFrame

# %%
len(data)

# %%
# Check dataframe shape (number of rows, number of columns)
data.shape
# Out:
# (973, 12)

# %%
# Print column names
data.columns.values

# %%
# Print index
data.index
# Out:
# RangeIndex(start=0, stop=973, step=1)

# %%
# Print data types
data.dtypes
# Out:
# year       int64
# month      int64
# meant    float64
# maxtp    float64
# mintp    float64
# mnmax    float64
# mnmin    float64
# rain     float64
# gmin         str
# wdsp     float64
# maxgt        str
# sun      float64
# dtype: object

# %% [markdown]
# ### Select specific columns

# %%
selection = data[['year','rain', 'sun']]
selection
# Out:
#      year   rain    sun
# 0    1941   67.2   56.1
# 1    1941   41.7   46.1
# 2    1942   91.9   72.8
# 3    1942   25.8   51.4
# 4    1942   76.4   73.9
# ..    ...    ...    ...
# 968  2022   29.6  131.6
# 969  2022   34.6  222.0
# 970  2022  127.9  112.9
# 971  2022  106.8  115.7
# 972  2022   46.1   84.5
#
# [973 rows x 3 columns]

# %%
type(selection)
# Out:
# pandas.DataFrame

# %%
selection.shape

# %% [markdown]
# Return only one of the columns:

# %%
data['meant']
# !pip show plotly
# Out:
# WARNING: Package(s) not found: plotly

# %%
type(data['meant'])
# Out:
# pandas.Series

# %% [markdown]
# You noticed that each time you had to create a new code cell to run your command and then wait for it to finish. Colab offers a different type of table, a so called interactive table, that lets you interact with the data more intuitively. Run the following code in order to activate interactive tables. Then all following tables will allow a richer experience with your  data exploration feedback loop.

# %%
# %pip install itables
from itables import init_notebook_mode, show

init_notebook_mode(all_interactive=True)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.4 MB 1.4 MB/s eta 0:00:02
#    ------------ --------------------------- 0.8/2.4 MB 1.2 MB/s eta 0:00:02
#    --------------------- ------------------ 1.3/2.4 MB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 1.6/2.4 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.1/2.4 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 1.6 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
# <script type="module">
#     const { set_or_remove_dark_class } = await import(window._itables_2_7_0);
#     set_or_remove_dark_class();
# </script>
# <script>
# ...

# %% [markdown]
# Now, load our dataset again and this time notice the richness of options for your data exploration.

# %%
data = pd.read_csv('mly532.csv', skiprows=19)
data
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin   rain   gmin  wdsp maxgt  \
# 0    1941     11    6.9   14.0   -3.1    9.9    3.9   67.2   -5.7  12.0
# 1    1941     12    6.5   12.7   -3.6    9.1    3.9   41.7   -7.6  12.5
# 2    1942      1    4.3   11.9   -3.1    6.9    1.7   91.9   -9.5  13.1
# 3    1942      2    2.9   11.6   -4.3    5.8   -0.0   25.8  -10.7   9.0
# 4    1942      3    6.3   16.2   -6.1    9.4    3.2   76.4   -8.3  10.7
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...   ...   ...
# 968  2022      7   16.3   29.1    6.6   21.0   11.7   29.6    0.0   8.1    33
# 969  2022      8   15.9   26.3    6.0   21.3   10.5   34.6    0.9   7.3    30
# 970  2022      9   13.0   20.1    3.1   17.2    8.8  127.9   -0.3   8.7    39
# 971  2022     10   12.0   18.0    1.3   15.6    8.4  106.8   -3.3   9.6    41
# 972  2022     11    8.8   16.5   -0.8   11.7    6.0   46.1   -3.5   9.9    51
#
#        sun
# 0     56.1
# 1     46.1
# 2     72.8
# 3     51.4
# ...

# %% [markdown]
# ## Descriptive Statistics
# Let's describe our temperature data set a little to understand it better.

# %%
data['meant'].mean()
# Out:
# np.float64(9.569270298047279)

# %%
data.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data.mean()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\frame.py:14461, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
# ...

# %%
data.describe()
# Check the values.
# Does it make sense to get descritptive statistics for the year column?
# Out:
#               year       month       meant       maxtp       mintp  \
# count   973.000000  973.000000  973.000000  973.000000  973.000000
# mean   1981.874615    6.504625    9.569270   17.775128    0.816958
# std      23.419302    3.455066    3.817761    4.373362    4.063796
# min    1941.000000    1.000000   -0.100000    4.800000  -12.200000
# 25%    1962.000000    4.000000    6.300000   13.900000   -2.100000
# 50%    1982.000000    7.000000    9.100000   17.400000    0.400000
# 75%    2002.000000   10.000000   13.100000   21.500000    4.200000
# max    2022.000000   12.000000   17.700000   29.100000   10.000000
#
#             mnmax       mnmin        rain        wdsp         sun
# count  973.000000  973.000000  973.000000  973.000000  973.000000
# mean    13.017369    6.121891   62.890442   10.226927  122.166598
# std      4.275961    3.438463   34.250328    2.137899   55.102597
# min      1.900000   -3.500000    3.600000    0.000000   16.400000
# ...

# %% [markdown]
# ###Task 14
# Show descriptive statistics only for those columns where it makes sense. Be mindful of your data type. You are selecting from a list (make sure you use enough square brackets).

# %%
data[['meant', 'maxtp', "mintp", "mnmax", "mnmin", "rain", "wdsp", "sun"]].describe()
# Out:
#             meant       maxtp       mintp       mnmax       mnmin        rain  \
# count  973.000000  973.000000  973.000000  973.000000  973.000000  973.000000
# mean     9.569270   17.775128    0.816958   13.017369    6.121891   62.890442
# std      3.817761    4.373362    4.063796    4.275961    3.438463   34.250328
# min     -0.100000    4.800000  -12.200000    1.900000   -3.500000    3.600000
# 25%      6.300000   13.900000   -2.100000    9.400000    3.300000   39.100000
# 50%      9.100000   17.400000    0.400000   12.700000    5.500000   56.600000
# 75%     13.100000   21.500000    4.200000   17.000000    9.200000   83.100000
# max     17.700000   29.100000   10.000000   22.900000   13.600000  217.000000
#
#              wdsp         sun
# count  973.000000  973.000000
# mean    10.226927  122.166598
# std      2.137899   55.102597
# min      0.000000   16.400000
# 25%      8.800000   73.500000
# 50%     10.100000  119.100000
# 75%     11.600000  161.800000
# ...

# %% [markdown]
# ### Defining a new column.

# %%
data['DIFF'] = 0.0

# %%
data
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin   rain   gmin  wdsp maxgt  \
# 0    1941     11    6.9   14.0   -3.1    9.9    3.9   67.2   -5.7  12.0
# 1    1941     12    6.5   12.7   -3.6    9.1    3.9   41.7   -7.6  12.5
# 2    1942      1    4.3   11.9   -3.1    6.9    1.7   91.9   -9.5  13.1
# 3    1942      2    2.9   11.6   -4.3    5.8   -0.0   25.8  -10.7   9.0
# 4    1942      3    6.3   16.2   -6.1    9.4    3.2   76.4   -8.3  10.7
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...   ...   ...
# 968  2022      7   16.3   29.1    6.6   21.0   11.7   29.6    0.0   8.1    33
# 969  2022      8   15.9   26.3    6.0   21.3   10.5   34.6    0.9   7.3    30
# 970  2022      9   13.0   20.1    3.1   17.2    8.8  127.9   -0.3   8.7    39
# 971  2022     10   12.0   18.0    1.3   15.6    8.4  106.8   -3.3   9.6    41
# 972  2022     11    8.8   16.5   -0.8   11.7    6.0   46.1   -3.5   9.9    51
#
#        sun  DIFF
# 0     56.1   0.0
# 1     46.1   0.0
# ...

# %%
data["DIFF"] = data["maxtp"] - data["mintp"]
data.head()
# Out:
#    year  month  meant  maxtp  mintp  mnmax  mnmin  rain   gmin  wdsp maxgt  \
# 0  1941     11    6.9   14.0   -3.1    9.9    3.9  67.2   -5.7  12.0
# 1  1941     12    6.5   12.7   -3.6    9.1    3.9  41.7   -7.6  12.5
# 2  1942      1    4.3   11.9   -3.1    6.9    1.7  91.9   -9.5  13.1
# 3  1942      2    2.9   11.6   -4.3    5.8   -0.0  25.8  -10.7   9.0
# 4  1942      3    6.3   16.2   -6.1    9.4    3.2  76.4   -8.3  10.7
#
#     sun  DIFF
# 0  56.1  17.1
# 1  46.1  16.3
# 2  72.8  15.0
# 3  51.4  15.9
# 4  73.9  22.3

# %% [markdown]
# ### Selecting a Row using an Index
# `loc[]` gives us the row at a particular index. Index counting starts at 0.

# %%
row = data.loc[4]
row
# Out:
# year     1942
# month       3
# meant     6.3
# maxtp    16.2
# mintp    -6.1
# mnmax     9.4
# mnmin     3.2
# rain     76.4
# gmin     -8.3
# wdsp     10.7
# maxgt
# sun      73.9
# DIFF     22.3
# Name: 4, dtype: object

# %%
row['mintp']
# Out:
# np.float64(-6.1)

# %% [markdown]
# ### Select a single value based on a row and colum

# %%
selection = data.loc[0:5, ['meant', 'DIFF']]
selection
# Out:
#    meant  DIFF
# 0    6.9  17.1
# 1    6.5  16.3
# 2    4.3  15.0
# 3    2.9  15.9
# 4    6.3  22.3
# 5    8.4  15.4

# %%
selection.at[0, 'DIFF']
# Out:
# np.float64(17.1)

# %%
sel2 = data.loc[data['year']==1941]
sel2
# Out:
#    year  month  meant  maxtp  mintp  mnmax  mnmin  rain  gmin  wdsp maxgt  \
# 0  1941     11    6.9   14.0   -3.1    9.9    3.9  67.2  -5.7  12.0
# 1  1941     12    6.5   12.7   -3.6    9.1    3.9  41.7  -7.6  12.5
#
#     sun  DIFF
# 0  56.1  17.1
# 1  46.1  16.3

# %% [markdown]
# ### Selection by integer position

# %%
# pay attention to what is included and excluded in your selected range
data.iloc[0:5, 2:7]
# Out:
#    meant  maxtp  mintp  mnmax  mnmin
# 0    6.9   14.0   -3.1    9.9    3.9
# 1    6.5   12.7   -3.6    9.1    3.9
# 2    4.3   11.9   -3.1    6.9    1.7
# 3    2.9   11.6   -4.3    5.8   -0.0
# 4    6.3   16.2   -6.1    9.4    3.2

# %%
data.iloc[-1]

# %%
data.iloc[0,1]

# %%
data['DIFF'] > 24

# %%
big_difference = data.loc[data['DIFF']>24]
big_difference

# %%
big_difference = data.loc[(data['DIFF']>24) & (data['year'] > 2015)]
big_difference

# %%
# previous cell shows the original index lines for the rows
# reset these
big_difference = big_difference.reset_index(drop=True)
big_difference

# %% [markdown]
# # Exploration Example
# What is the mean temperature of the `maxtp` value for all the Junes starting in 2016 to the end of what has been recorded?

# %%
# prep to get to know the data and values
data[['year','maxtp']].loc[(data['month'] == 6)].loc[data['year']>=2016]

# %%
# same way of doing the above using only maxtp.
# Which one do you find more intuitive?
data['maxtp'].loc[(data['month'] == 6) & (data['year']>=2016)]

# %%
data['maxtp'].loc[(data['year'] >= 2016) & (data['month'] == 6)].mean()

# %% [markdown]
# In this lesson, we have stored subsets of a DataFrame as a new variable. In some cases, we are still referring to the original data and any modifications made to the new variable might influence the original DataFrame.
#
# If you want to be extra careful to not modify the original DataFrame, then you should take a proper copy of the data before proceeding using the `.copy() `method.

# %%
# Check if there are any missing values
data.isnull().values.any()

# %% [markdown]
# This is an unusually clean dataset. Often you need to handle null values, NAN values and empty values and consider what to do with them. Often, the rows are either deleted, or values are imputed on the basis of what's around them.

# %% [markdown]
# ### Groupby

# %%
grouped = data.groupby('month')
len(grouped)

# %%
type(grouped)

# %%
# Count distinct observations over requested axis
data['month'].nunique()

# %%
month = 3
group1 = grouped.get_group(month)
group1

# %%
type(group1)

# %% [markdown]
# As we can see, a single group contains a DataFrame with values only for that specific month.
# So, one group is a pandas DataFrame! This is really useful, because we can now use all the familiar DataFrame methods for calculating statistics etc for this specific group. We can, for example, calculate the average values for all variables using the statistical functions that we have seen already (e.g. mean, std, min, max, median, etc.).

# %%
mean_columns = ['rain', 'wdsp', 'sun']
mean_values = group1[mean_columns].mean()
mean_values

# %%
# Iterate over groups
for key, group in grouped:
    # Print key and group
    print("Key:\n", key)
    print("\nFirst rows of data in this group:\n", group.head())

    # Stop iteration with break command
    break

# %% [markdown]
# ### Writing data to file

# %%
output = "Very big differences.csv"
big_difference = data.loc[data['DIFF']>24]
big_difference = big_difference.reset_index(drop=True)
big_difference.to_csv(output, sep=',')
# This file is now available in your explorer view on the left

# %% [markdown]
# ### Our first plot

# %%
ax = data[["meant", "maxtp", "mintp"]].plot()

# %%
type(ax)

# %% [markdown]
# #### Selecting specific data for plotting

# %%
oct_temps = data['meant'].loc[data.month == 10]
ax = oct_temps.plot() # here it plots against the index position, not very intuitive

# %%
oct_temps = data[['year','meant']].loc[data.month == 10]
ax = oct_temps.plot(x='year', y='meant') # here we plot against the year, better!

# %%
# some basic plot formatting
oct_temps = data[['year','meant']].loc[data.month == 10]
ax = oct_temps.plot(style='ro--', title='Ireland\'s Temperatures in October',
                    x='year', y='meant')
ax.set_xlabel('Date')
ax.set_ylabel('Temperature [°C]')

# %%
# find out more about your plot formatting options

help(oct_temps.plot)

# %%
# to get rid of the gaps right and left

start_date = 1942
end_date = 2019

oct_temps = data[['year','meant']].loc[data.month == 10]
ax = oct_temps.plot(style='ro--', title='Ireland\'s Temperatures in October',
                    xlim=[start_date, end_date], ylim=[0, 20],
                    x='year', y='meant')
ax.set_xlabel('Date')
ax.set_ylabel('Temperature [°C]')

# %% [markdown]
# #### Bar Plots in Pandas

# %%
oct_temps = data[['year','meant']].loc[data.month == 10]
ax = oct_temps.plot(kind='bar', title='Ireland\'s Temperatures in October',
                         ylim=[0, 20], x = 'year', y = 'meant')
ax.set_xlabel('Date')
ax.set_ylabel('Temperature [°C]')

# %%
import matplotlib.pyplot as plt

# %%
# Saving your plot as a figure
oct_temps = data[['year','meant']].loc[data.month == 10]
ax = oct_temps.plot(kind='bar', title='Ireland\'s Temperatures in October',
                         ylim=[0, 20], x = 'year', y = 'meant')
ax.set_xlabel('Date')
ax.set_ylabel('Temperature [°C]')
plt.savefig('bar-plot-hi-res.pdf', dpi=600)

# %%
fig, ax = plt.subplots(figsize=(50, 15))

oct_temps = data[['year','meant']].loc[data.month == 10]
ax = oct_temps.plot(kind='bar', title='Ireland\'s Temperatures in October',
                         ylim=[0, 20], x = 'year', y = 'meant', ax=ax)
ax.set_xlabel('Date')
plt.xticks(fontsize=28, rotation=45)
ax.set_ylabel('Temperature [°C]')

# %% [markdown]
# There are many more settings and display options to explore as part of this course.
